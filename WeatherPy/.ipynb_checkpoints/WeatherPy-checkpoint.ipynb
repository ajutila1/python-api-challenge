# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 608

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?q="

city_name = []
lat = []
lng = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []


for city in cities:
    query = f"{url}{city}&appid={weather_api_key}"
    response = requests.get(query).json()
    try:
        city_name.append(response["name"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        max_temp.append(response["main"]["temp_max"])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        wind_speed.append(response["wind"]["speed"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        index = cities.index(city)
        print(f"Processing Record {index} of {len(cities)} | {city}")
    except:
        print(f"{city} data not found.")
# Out:
# Processing Record 0 of 608 | sao joao da barra
# Processing Record 1 of 608 | palafrugell
# Processing Record 2 of 608 | wadena
# Processing Record 3 of 608 | jamestown
# Processing Record 4 of 608 | visby
# Processing Record 5 of 608 | hobart
# Processing Record 6 of 608 | hermanus
# Processing Record 7 of 608 | qaanaaq
# illoqqortoormiut data not found.
# Processing Record 9 of 608 | hilo
# Processing Record 10 of 608 | punta arenas
# Processing Record 11 of 608 | dikson
# Processing Record 12 of 608 | tuktoyaktuk
# Processing Record 13 of 608 | cowansville
# Processing Record 14 of 608 | ushuaia
# Processing Record 15 of 608 | san cristobal
# mys shmidta data not found.
# Processing Record 17 of 608 | hualmay
# Processing Record 18 of 608 | saint-philippe
# Processing Record 19 of 608 | port alfred
# Processing Record 20 of 608 | ranong
# Processing Record 21 of 608 | provideniya
# Processing Record 22 of 608 | bluff
# Processing Record 23 of 608 | airai
# Processing Record 24 of 608 | prince george
# Processing Record 25 of 608 | kingsport
# Processing Record 26 of 608 | lagoa
# Processing Record 27 of 608 | moerai
# Processing Record 28 of 608 | batagay-alyta
# Processing Record 29 of 608 | zhigansk
# Processing Record 30 of 608 | albany
# Processing Record 31 of 608 | kapaa
# Processing Record 32 of 608 | luderitz
# Processing Record 33 of 608 | vila velha
# Processing Record 34 of 608 | thompson
# Processing Record 35 of 608 | barrow
# Processing Record 36 of 608 | mataura
# Processing Record 37 of 608 | rikitea
# Processing Record 38 of 608 | hithadhoo
# Processing Record 39 of 608 | busselton
# boatlaname data not found.
# Processing Record 41 of 608 | faanui
# Processing Record 42 of 608 | tasiilaq
# Processing Record 43 of 608 | ishim
# Processing Record 44 of 608 | golden
# Processing Record 45 of 608 | anadyr
# Processing Record 46 of 608 | nikolskoye
# Processing Record 47 of 608 | ossora
# Processing Record 48 of 608 | sakakah
# parras data not found.
# Processing Record 50 of 608 | lorengau
# Processing Record 51 of 608 | atuona
# saleaula data not found.
# tasbuget data not found.
# Processing Record 54 of 608 | hokitika
# Processing Record 55 of 608 | yashan
# Processing Record 56 of 608 | shimoda
# Processing Record 57 of 608 | sladkovo
# Processing Record 58 of 608 | svecha
# Processing Record 59 of 608 | mercedes
# Processing Record 60 of 608 | nhulunbuy
# Processing Record 61 of 608 | bredasdorp
# Processing Record 62 of 608 | constitucion
# Processing Record 63 of 608 | saint simons
# Processing Record 64 of 608 | east london
# Processing Record 65 of 608 | codrington
# Processing Record 66 of 608 | avarua
# Processing Record 67 of 608 | dhidhdhoo
# Processing Record 68 of 608 | sinnamary
# Processing Record 69 of 608 | laguna
# Processing Record 70 of 608 | henties bay
# Processing Record 71 of 608 | hanno
# Processing Record 72 of 608 | amahai
# Processing Record 73 of 608 | vaini
# Processing Record 74 of 608 | yar-sale
# yeltsovka data not found.
# Processing Record 76 of 608 | cabo san lucas
# roches noires data not found.
# Processing Record 78 of 608 | kijang
# Processing Record 79 of 608 | lae
# Processing Record 80 of 608 | goure
# Processing Record 81 of 608 | sitka
# Processing Record 82 of 608 | quang ngai
# marcona data not found.
# Processing Record 84 of 608 | saldanha
# Processing Record 85 of 608 | miles city
# Processing Record 86 of 608 | voloshka
# Processing Record 87 of 608 | half moon bay
# louisbourg data not found.
# Processing Record 89 of 608 | chuy
# Processing Record 90 of 608 | carnarvon
# Processing Record 91 of 608 | evensk
# Processing Record 92 of 608 | ancud
# Processing Record 93 of 608 | southbridge
# Processing Record 94 of 608 | isiro
# Processing Record 95 of 608 | geraldton
# taolanaro data not found.
# Processing Record 97 of 608 | kedrovyy
# Processing Record 98 of 608 | lima duarte
# Processing Record 99 of 608 | zharkent
# Processing Record 100 of 608 | sonqor
# Processing Record 101 of 608 | comodoro rivadavia
# Processing Record 102 of 608 | bathsheba
# Processing Record 103 of 608 | kodiak
# Processing Record 104 of 608 | mao
# Processing Record 105 of 608 | licata
# Processing Record 106 of 608 | nanakuli
# Processing Record 107 of 608 | longyearbyen
# vaitupu data not found.
# Processing Record 109 of 608 | chamba
# Processing Record 110 of 608 | umm lajj
# Processing Record 111 of 608 | avera
# Processing Record 112 of 608 | birin
# Processing Record 113 of 608 | dingle
# Processing Record 114 of 608 | sangueya
# Processing Record 115 of 608 | mount gambier
# Processing Record 116 of 608 | kahului
# Processing Record 117 of 608 | arraial do cabo
# Processing Record 118 of 608 | yulara
# Processing Record 119 of 608 | poronaysk
# Processing Record 120 of 608 | kharovsk
# Processing Record 121 of 608 | sangar
# Processing Record 122 of 608 | tommot
# Processing Record 123 of 608 | aleksandrov gay
# Processing Record 124 of 608 | butaritari
# Processing Record 125 of 608 | narsaq
# Processing Record 126 of 608 | kemi
# Processing Record 127 of 608 | castro
# Processing Record 128 of 608 | monte patria
# Processing Record 129 of 608 | lebu
# Processing Record 130 of 608 | ashford
# Processing Record 131 of 608 | luanda
# malwan data not found.
# Processing Record 133 of 608 | gawler
# Processing Record 134 of 608 | yellowknife
# Processing Record 135 of 608 | rawson
# Processing Record 136 of 608 | hangu
# Processing Record 137 of 608 | cape town
# Processing Record 138 of 608 | upington
# Processing Record 139 of 608 | champawat
# Processing Record 140 of 608 | hobyo
# Processing Record 141 of 608 | coihaique
# Processing Record 142 of 608 | mar del plata
# Processing Record 143 of 608 | clyde river
# Processing Record 144 of 608 | mahebourg
# Processing Record 145 of 608 | pochutla
# Processing Record 146 of 608 | kaeo
# Processing Record 147 of 608 | severo-kurilsk
# attawapiskat data not found.
# Processing Record 149 of 608 | altamont
# Processing Record 150 of 608 | boa esperanca do sul
# Processing Record 151 of 608 | upernavik
# Processing Record 152 of 608 | coquimbo
# Processing Record 153 of 608 | te anau
# Processing Record 154 of 608 | grindavik
# Processing Record 155 of 608 | bom jesus
# Processing Record 156 of 608 | verkhoyansk
# Processing Record 157 of 608 | paramonga
# Processing Record 158 of 608 | dakar
# Processing Record 159 of 608 | qianan
# Processing Record 160 of 608 | galveston
# Processing Record 161 of 608 | eyl
# Processing Record 162 of 608 | saskylakh
# Processing Record 163 of 608 | georgetown
# Processing Record 164 of 608 | puerto baquerizo moreno
# Processing Record 165 of 608 | khasan
# Processing Record 166 of 608 | ketchikan
# Processing Record 167 of 608 | roald
# Processing Record 168 of 608 | vao
# Processing Record 169 of 608 | torbay
# Processing Record 170 of 608 | tuatapere
# Processing Record 171 of 608 | denpasar
# Processing Record 172 of 608 | port hardy
# Processing Record 173 of 608 | biryukove
# Processing Record 174 of 608 | amos
# Processing Record 175 of 608 | bethel
# mme data not found.
# Processing Record 177 of 608 | cidreira
# Processing Record 178 of 608 | saint-georges
# Processing Record 179 of 608 | orlik
# samusu data not found.
# Processing Record 181 of 608 | steamboat springs
# belushya guba data not found.
# Processing Record 183 of 608 | esperance
# Processing Record 184 of 608 | ilulissat
# khonuu data not found.
# Processing Record 186 of 608 | yima
# Processing Record 187 of 608 | kavieng
# Processing Record 188 of 608 | iqaluit
# Processing Record 189 of 608 | tiruchchendur
# Processing Record 190 of 608 | victoria
# Processing Record 191 of 608 | tabuk
# Processing Record 192 of 608 | portland
# Processing Record 193 of 608 | monaco-ville
# Processing Record 194 of 608 | blackwater
# Processing Record 195 of 608 | meulaboh
# Processing Record 196 of 608 | iquitos
# Processing Record 197 of 608 | batemans bay
# Processing Record 198 of 608 | egvekinot
# Processing Record 199 of 608 | khatanga
# Processing Record 200 of 608 | bandar-e anzali
# Processing Record 201 of 608 | curvelo
# Processing Record 202 of 608 | ponta do sol
# Processing Record 203 of 608 | chenghai
# Processing Record 204 of 608 | havre
# Processing Record 205 of 608 | new norfolk
# Processing Record 206 of 608 | bengkulu
# sinjah data not found.
# Processing Record 208 of 608 | wanning
# Processing Record 209 of 608 | san quintin
# Processing Record 210 of 608 | kindu
# Processing Record 211 of 608 | lavrentiya
# Processing Record 212 of 608 | namatanai
# Processing Record 213 of 608 | kaitangata
# Processing Record 214 of 608 | menongue
# Processing Record 215 of 608 | nanortalik
# Processing Record 216 of 608 | cherskiy
# Processing Record 217 of 608 | ostrovnoy
# Processing Record 218 of 608 | trincomalee
# Processing Record 219 of 608 | husavik
# Processing Record 220 of 608 | kromy
# Processing Record 221 of 608 | dharchula
# Processing Record 222 of 608 | dobson
# duz data not found.
# Processing Record 224 of 608 | fare
# chagda data not found.
# Processing Record 226 of 608 | sola
# Processing Record 227 of 608 | alice springs
# Processing Record 228 of 608 | linxia
# Processing Record 229 of 608 | port elizabeth
# Processing Record 230 of 608 | ciudad del maiz
# Processing Record 231 of 608 | the valley
# Processing Record 232 of 608 | lamar
# sentyabrskiy data not found.
# Processing Record 234 of 608 | vanderhoof
# Processing Record 235 of 608 | celestun
# barentsburg data not found.
# Processing Record 237 of 608 | hasaki
# Processing Record 238 of 608 | tuy hoa
# Processing Record 239 of 608 | olafsvik
# Processing Record 240 of 608 | flinders
# Processing Record 241 of 608 | asau
# Processing Record 242 of 608 | gizo
# Processing Record 243 of 608 | nadym
# Processing Record 244 of 608 | cholet
# Processing Record 245 of 608 | padang
# Processing Record 246 of 608 | inhambane
# Processing Record 247 of 608 | vardo
# Processing Record 248 of 608 | cedar city
# Processing Record 249 of 608 | bandarbeyla
# Processing Record 250 of 608 | marathon
# Processing Record 251 of 608 | jumla
# yandoon data not found.
# Processing Record 253 of 608 | carutapera
# Processing Record 254 of 608 | ribeira grande
# Processing Record 255 of 608 | rochegda
# Processing Record 256 of 608 | tezu
# nizhneyansk data not found.
# Processing Record 258 of 608 | saint anthony
# Processing Record 259 of 608 | ambon
# huazolotitlan data not found.
# Processing Record 261 of 608 | kieta
# Processing Record 262 of 608 | salgado
# Processing Record 263 of 608 | port moresby
# Processing Record 264 of 608 | mount isa
# Processing Record 265 of 608 | glenwood springs
# Processing Record 266 of 608 | jaru
# Processing Record 267 of 608 | bambanglipuro
# Processing Record 268 of 608 | varna
# Processing Record 269 of 608 | mazagao
# Processing Record 270 of 608 | shelburne
# Processing Record 271 of 608 | erice
# Processing Record 272 of 608 | tsagan aman
# haibowan data not found.
# Processing Record 274 of 608 | metro
# Processing Record 275 of 608 | saint-paul
# Processing Record 276 of 608 | nouadhibou
# Processing Record 277 of 608 | bereda
# grand river south east data not found.
# Processing Record 279 of 608 | los llanos de aridane
# Processing Record 280 of 608 | margate
# Processing Record 281 of 608 | santa ines
# Processing Record 282 of 608 | cabedelo
# Processing Record 283 of 608 | inuvik
# Processing Record 284 of 608 | port macquarie
# Processing Record 285 of 608 | doha
# talawdi data not found.
# Processing Record 287 of 608 | norman wells
# Processing Record 288 of 608 | puerto ayora
# Processing Record 289 of 608 | hambantota
# Processing Record 290 of 608 | alta floresta
# Processing Record 291 of 608 | salalah
# Processing Record 292 of 608 | gornopravdinsk
# Processing Record 293 of 608 | touros
# Processing Record 294 of 608 | morgan city
# Processing Record 295 of 608 | bako
# Processing Record 296 of 608 | lingyuan
# Processing Record 297 of 608 | jalu
# Processing Record 298 of 608 | las vegas
# Processing Record 299 of 608 | hue
# Processing Record 300 of 608 | gat
# Processing Record 301 of 608 | hlobyne
# Processing Record 302 of 608 | boysun
# Processing Record 303 of 608 | innisfail
# Processing Record 304 of 608 | solnechnyy
# Processing Record 305 of 608 | burley
# Processing Record 306 of 608 | atbasar
# Processing Record 307 of 608 | miguel hidalgo
# Processing Record 308 of 608 | pacific grove
# Processing Record 309 of 608 | miri
# Processing Record 310 of 608 | chokurdakh
# Processing Record 311 of 608 | bambous virieux
# Processing Record 312 of 608 | nara
# Processing Record 313 of 608 | gedo
# Processing Record 314 of 608 | oviedo
# Processing Record 315 of 608 | hofn
# Processing Record 316 of 608 | barcelos
# Processing Record 317 of 608 | oistins
# Processing Record 318 of 608 | severo-yeniseyskiy
# Processing Record 319 of 608 | marystown
# Processing Record 320 of 608 | chernyshevskiy
# bokspits data not found.
# Processing Record 322 of 608 | leningradskiy
# Processing Record 323 of 608 | rio grande
# Processing Record 324 of 608 | tiksi
# Processing Record 325 of 608 | neiafu
# Processing Record 326 of 608 | sao filipe
# Processing Record 327 of 608 | college
# Processing Record 328 of 608 | tukan
# Processing Record 329 of 608 | makakilo city
# Processing Record 330 of 608 | deputatskiy
# Processing Record 331 of 608 | eshowe
# Processing Record 332 of 608 | ulaanbaatar
# Processing Record 333 of 608 | xichang
# Processing Record 334 of 608 | okhotsk
# Processing Record 335 of 608 | porto novo
# Processing Record 336 of 608 | mareeba
# Processing Record 337 of 608 | barra dos coqueiros
# nguiu data not found.
# Processing Record 339 of 608 | lucea
# Processing Record 340 of 608 | aswan
# Processing Record 341 of 608 | mersing
# tsihombe data not found.
# Processing Record 343 of 608 | tucuman
# Processing Record 344 of 608 | kruisfontein
# dujuma data not found.
# el faiyum data not found.
# Processing Record 347 of 608 | lasa
# Processing Record 348 of 608 | pangnirtung
# Processing Record 349 of 608 | khanpur
# Processing Record 350 of 608 | indian head
# Processing Record 351 of 608 | fort wayne
# Processing Record 352 of 608 | saint george
# Processing Record 353 of 608 | kirovskiy
# Processing Record 354 of 608 | songea
# Processing Record 355 of 608 | plettenberg bay
# Processing Record 356 of 608 | lompoc
# Processing Record 357 of 608 | carnduff
# Processing Record 358 of 608 | mandurah
# Processing Record 359 of 608 | burnie
# Processing Record 360 of 608 | inverness
# Processing Record 361 of 608 | veraval
# Processing Record 362 of 608 | panzhihua
# Processing Record 363 of 608 | lecce
# Processing Record 364 of 608 | dunedin
# Processing Record 365 of 608 | mocuba
# Processing Record 366 of 608 | kaka
# Processing Record 367 of 608 | luena
# Processing Record 368 of 608 | columbus
# Processing Record 369 of 608 | mirnyy
# Processing Record 370 of 608 | seabra
# Processing Record 371 of 608 | maniitsoq
# Processing Record 372 of 608 | aklavik
# Processing Record 373 of 608 | mahajanga
# Processing Record 374 of 608 | port blair
# Processing Record 375 of 608 | chakrata
# Processing Record 376 of 608 | bogale
# Processing Record 377 of 608 | kendari
# doctor pedro p. pena data not found.
# Processing Record 379 of 608 | itoman
# rungata data not found.
# Processing Record 381 of 608 | omboue
# Processing Record 382 of 608 | whitehorse
# Processing Record 383 of 608 | walker
# Processing Record 384 of 608 | avigliana
# Processing Record 385 of 608 | baruun-urt
# Processing Record 386 of 608 | srednekolymsk
# Processing Record 387 of 608 | buin
# Processing Record 388 of 608 | liberty
# Processing Record 389 of 608 | bubaque
# Processing Record 390 of 608 | aksha
# Processing Record 391 of 608 | rosetta
# Processing Record 392 of 608 | ulladulla
# Processing Record 393 of 608 | fairbanks
# Processing Record 394 of 608 | nagato
# Processing Record 395 of 608 | shambu
# Processing Record 396 of 608 | marialva
# Processing Record 397 of 608 | tutoia
# Processing Record 398 of 608 | nishihara
# Processing Record 399 of 608 | kathu
# Processing Record 400 of 608 | balatonlelle
# Processing Record 401 of 608 | ust-nera
# Processing Record 402 of 608 | soure
# Processing Record 403 of 608 | castelfranco emilia
# Processing Record 404 of 608 | rosarito
# tome-acu data not found.
# Processing Record 406 of 608 | kilindoni
# Processing Record 407 of 608 | scarborough
# Processing Record 408 of 608 | vung tau
# subaytilah data not found.
# Processing Record 410 of 608 | klaksvik
# labutta data not found.
# Processing Record 412 of 608 | yarada
# Processing Record 413 of 608 | kloulklubed
# Processing Record 414 of 608 | waipawa
# Processing Record 415 of 608 | mana
# Processing Record 416 of 608 | remedios
# Processing Record 417 of 608 | sibu
# Processing Record 418 of 608 | phan thiet
# lar gerd data not found.
# Processing Record 420 of 608 | kiama
# Processing Record 421 of 608 | miraflores
# satitoa data not found.
# Processing Record 423 of 608 | pokrovsk
# Processing Record 424 of 608 | peniche
# Processing Record 425 of 608 | kenai
# Processing Record 426 of 608 | ust-tsilma
# Processing Record 427 of 608 | xihe
# burica data not found.
# Processing Record 429 of 608 | baiima
# Processing Record 430 of 608 | pingliang
# Processing Record 431 of 608 | katsuura
# Processing Record 432 of 608 | jurado
# Processing Record 433 of 608 | rusape
# Processing Record 434 of 608 | arkadelphia
# Processing Record 435 of 608 | quatre cocos
# Processing Record 436 of 608 | grand gaube
# Processing Record 437 of 608 | shingu
# Processing Record 438 of 608 | san patricio
# Processing Record 439 of 608 | kannur
# Processing Record 440 of 608 | stornoway
# georgiu-dezh data not found.
# Processing Record 442 of 608 | bilma
# Processing Record 443 of 608 | nizhniy ingash
# Processing Record 444 of 608 | odessa
# Processing Record 445 of 608 | lazaro cardenas
# Processing Record 446 of 608 | awjilah
# Processing Record 447 of 608 | palmer
# Processing Record 448 of 608 | tigre
# Processing Record 449 of 608 | matamoros
# Processing Record 450 of 608 | goderich
# Processing Record 451 of 608 | algiers
# Processing Record 452 of 608 | birjand
# Processing Record 453 of 608 | souillac
# Processing Record 454 of 608 | dudinka
# Processing Record 455 of 608 | charters towers
# Processing Record 456 of 608 | ranau
# Processing Record 457 of 608 | fortuna
# Processing Record 458 of 608 | plouzane
# Processing Record 459 of 608 | durango
# Processing Record 460 of 608 | abalak
# Processing Record 461 of 608 | rio gallegos
# Processing Record 462 of 608 | mariveles
# Processing Record 463 of 608 | tynda
# Processing Record 464 of 608 | kangaatsiaq
# Processing Record 465 of 608 | talnakh
# tocantinopolis data not found.
# Processing Record 467 of 608 | havelock
# Processing Record 468 of 608 | kenora
# Processing Record 469 of 608 | wagar
# Processing Record 470 of 608 | chipoka
# Processing Record 471 of 608 | shenjiamen
# Processing Record 472 of 608 | yeppoon
# Processing Record 473 of 608 | longyan
# Processing Record 474 of 608 | bure
# Processing Record 475 of 608 | chicama
# amderma data not found.
# Processing Record 477 of 608 | camden
# Processing Record 478 of 608 | pevek
# Processing Record 479 of 608 | tiarei
# lolua data not found.
# Processing Record 481 of 608 | hailey
# borlange data not found.
# Processing Record 483 of 608 | pacifica
# yialos data not found.
# tumannyy data not found.
# Processing Record 486 of 608 | tarko-sale
# Processing Record 487 of 608 | qaqortoq
# Processing Record 488 of 608 | agadez
# Processing Record 489 of 608 | morondava
# Processing Record 490 of 608 | manggar
# Processing Record 491 of 608 | ambilobe
# Processing Record 492 of 608 | vanimo
# Processing Record 493 of 608 | viedma
# Processing Record 494 of 608 | kumertau
# Processing Record 495 of 608 | trairi
# Processing Record 496 of 608 | govardhan
# Processing Record 497 of 608 | deloraine
# Processing Record 498 of 608 | phalombe
# Processing Record 499 of 608 | zolotepec
# Processing Record 500 of 608 | mitu
# Processing Record 501 of 608 | coruripe
# Processing Record 502 of 608 | sterling
# Processing Record 503 of 608 | tipperary
# Processing Record 504 of 608 | ishinomaki
# Processing Record 505 of 608 | baykit
# Processing Record 506 of 608 | beni suef
# Processing Record 507 of 608 | krasnyy yar
# Processing Record 508 of 608 | gariaband
# Processing Record 509 of 608 | pokhara
# Processing Record 510 of 608 | belyy yar
# Processing Record 511 of 608 | saint-augustin
# Processing Record 512 of 608 | montepuez
# guelengdeng data not found.
# Processing Record 514 of 608 | hawalli
# Processing Record 515 of 608 | bar harbor
# Processing Record 516 of 608 | wadgassen
# Processing Record 517 of 608 | tigil
# Processing Record 518 of 608 | nuuk
# Processing Record 519 of 608 | robertsport
# Processing Record 520 of 608 | grapevine
# Processing Record 521 of 608 | mayo
# Processing Record 522 of 608 | guerrero negro

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_api_df = pd.DataFrame({"City": city_name, "Latitude": lat, "Longitude": lng, "Max Temperature": max_temp,
                             "Humidity": humidity, "Cloudiness": cloudiness, "Wind Speed": wind_speed, "Country": country,
                             "Date": date})
weather_api_df["Max Temperature"] = (((weather_api_df["Max Temperature"])*(9/5))-459.67)
weather_api_df["Wind Speed"] = weather_api_df["Wind Speed"]*2.23694

weather_api_df
weather_api_df.to_csv("output_data/cities.csv")

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
# Extract relevant fields from the data frame


# Export the City_Data into a csv

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
today = pd.to_datetime("today").strftime('%Y-%m-%d')

plt.scatter(weather_api_df["Latitude"], weather_api_df["Max Temperature"], edgecolors="black")
plt.xlabel("Latitude")
plt.ylabel(f"Max Temperature (F)")
plt.title(f"City Latitude vs. Max Temperature ({today})")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(weather_api_df["Latitude"], weather_api_df["Humidity"], edgecolors="black")
plt.xlabel("Latitude")
plt.ylabel(f"Humidity (%)")
plt.title(f"City Latitude vs. Humidity ({today})")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_api_df["Latitude"], weather_api_df["Cloudiness"], edgecolors="black")
plt.xlabel("Latitude")
plt.ylabel(f"Cloudiness (%)")
plt.title(f"City Latitude vs. Cloudiness ({today})")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_api_df["Latitude"], weather_api_df["Wind Speed"], edgecolors="black")
plt.xlabel("Latitude")
plt.ylabel(f"Wind Speed (mph)")
plt.title(f"City Latitude vs. Wind Speed ({today})")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def Linear_Regression():
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values.astype(float), y_values.astype(float))
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,(6,0),fontsize=15,color="red")

# %%
# Create Northern and Southern Hemisphere DataFrames
north_cities = weather_api_df.loc[(weather_api_df["Latitude"]>0)]

south_cities = weather_api_df.loc[(weather_api_df["Latitude"]<0)]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = north_cities["Latitude"]
y_values = north_cities["Max Temperature"]

Linear_Regression()
plt.xlabel("Latitude")
plt.ylabel(f"Max Temperature (F)")
plt.title(f"Northern Hemisphere vs. Max Temperature ({today})")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = south_cities["Latitude"]
y_values = south_cities["Max Temperature"]

Linear_Regression()

plt.xlabel("Latitude")
plt.ylabel(f"Max Temperature (F)")
plt.title(f"Southern Hemisphere vs. Max Temperature ({today})")
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = north_cities["Latitude"]
y_values = north_cities["Humidity"]

Linear_Regression()
plt.xlabel("Latitude")
plt.ylabel(f"Humidity (%)")
plt.title(f"Northern Hemisphere vs. Humidity ({today})")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = south_cities["Latitude"]
y_values = south_cities["Humidity"]

Linear_Regression()
plt.xlabel("Latitude")
plt.ylabel(f"Humidity (%)")
plt.title(f"Southern Hemisphere vs. Humidity ({today})")
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = north_cities["Latitude"]
y_values = north_cities["Cloudiness"]

Linear_Regression()
plt.xlabel("Latitude")
plt.ylabel(f"Cloudiness (%)")
plt.title(f"Northern Hemisphere vs. Cloudiness ({today})")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = south_cities["Latitude"]
y_values = south_cities["Humidity"]

Linear_Regression()
plt.xlabel("Latitude")
plt.ylabel(f"Humidity (%)")
plt.title(f"Southern Hemisphere vs. Cloudiness ({today})")
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = north_cities["Latitude"]
y_values = north_cities["Wind Speed"]

Linear_Regression()
plt.xlabel("Latitude")
plt.ylabel(f"Wind Speed (mph)")
plt.title(f"Northern Hemisphere vs. Wind Speed ({today})")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = south_cities["Latitude"]
y_values = south_cities["Wind Speed"]

Linear_Regression()
plt.xlabel("Latitude")
plt.ylabel(f"Wind Speed (mph)")
plt.title(f"Southern Hemisphere vs. Wind Speed ({today})")
plt.show()
